# %%
import pandas as pd
import numpy as np

# %%
import time
from  datetime import date

# %%
data = pd.read_excel('/home/ekim_reverse/PyCode/study/Python.study/toy_project/online_news_pn_num_2.xlsx')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#     Index                                            content  \
# 0  198930  삼성전자의 주종목이 종합반도체로 바뀌는 걸까. 올해 삼성전자의 반도체 부문 영업이익...
# 1  198929  ‘전자업계 효자’ 2015년에도 질주삼성, 中시안 공장 1조 들여 증산… SK, 1...
# 2  198928  [이데일리 김보리 조진영 기자] 중국의 스마트폰 샤오미(小米)는 ‘짝퉁 애플’이란 ...
# 3  198926  ◆ 2015 업종별 유망주 ① IT·전자 ◆\n\n\n‘반도체 호황의 지속, 대형 ...
# 4  198927  ‘상저하고(上低下高·주가가 상반기에 부진하고 하반기에는 올라가는 것 ), 지배구조·...
#
#                  created_date publisher  section  \
# 0  2015-01-01T02:22:00.000000      서울신문  economy
# 1  2015-01-01T03:02:00.000000      동아일보  economy
# 2  2015-01-01T03:06:00.000000      이데일리  economy
# 3  2015-01-01T04:03:00.000000      매일경제  economy
# 4  2015-01-01T04:03:00.000000      매일경제  economy
#
#                                   title      분기  실질GDP  \
# 0               D램 매출 14%↑… 반도체 새해도 호황기  2015Q1    2.5
# 1            으랏차차, 반도체… ‘14조 대박신화’ 이어간다  2015Q1    2.5
# 2  [광복70년]고사 직전 제조업 ‘규제완화·내수활성화’ 링거 꽂아야  2015Q1    2.5
# 3              삼성전자 바닥 치고 2분기부터 실적 개선될듯  2015Q1    2.5
# ...

# %%
data1 = data.loc[:,['created_date','c_pn_num']]

# %%
data1
# Out:
#                      created_date  c_pn_num
# 0      2015-01-01T02:22:00.000000      0.00
# 1      2015-01-01T03:02:00.000000      0.00
# 2      2015-01-01T03:06:00.000000     -0.02
# 3      2015-01-01T04:03:00.000000      0.02
# 4      2015-01-01T04:03:00.000000      0.00
# ...                           ...       ...
# 86377  2016-12-31T19:09:00.000000      0.00
# 86378  2016-12-31T19:43:00.000000      0.00
# 86379  2016-12-31T20:28:00.000000      0.00
# 86380  2016-12-31T22:29:00.000000      0.00
# 86381  2016-12-31T23:45:00.000000      0.00
#
# [86382 rows x 2 columns]

# %%
type(data1['created_date'])
# Out:
# pandas.core.series.Series
