# %%
import pandas as pd
import numpy as np
import lda
import keras
import tensorflow as tf
import gensim
from gensim import corpora
from gensim.corpora.dictionary import Dictionary
from konlpy.tag import Okt
t = Okt()
# Out:
# Using TensorFlow backend.
# /home/ekim_reverse/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ekim_reverse/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ekim_reverse/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ekim_reverse/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ekim_reverse/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ekim_reverse/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/ekim_reverse/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ekim_reverse/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ekim_reverse/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ekim_reverse/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ekim_reverse/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ekim_reverse/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
data = pd.read_csv('/home/ekim_reverse/study/Python.study/toy_project/online_news_test.csv')
vocab = pd.read_csv('/home/ekim_reverse/study/Python.study/toy_project/stop_words.csv', encoding = 'cp949')

# %%
for line in data['content']:        #형태소분석기
    news_word = t.pos(line)

# %%
news_word[1]
# Out:
# ('MU', 'Alpha')

# %%
result_word = []              # 명사, 동사, 형용사만 추출
target = ["Noun","Verb","Adjective"]

for word in news_word:
    if word[1] in target:
        result_word.append(word)

# %%
result_word
# Out:
# [('지원', 'Noun'),
#  ('하는', 'Verb'),
#  ('칩셋', 'Noun'),
#  ('고급', 'Noun'),
#  ('홈', 'Noun'),
#  ('게이트웨이', 'Noun'),
#  ('셋톱박스', 'Noun'),
#  ('비디오', 'Noun'),
#  ('브리지', 'Noun'),
#  ('라우터', 'Noun'),
#  ('및', 'Noun'),
#  ('엔터프라이즈', 'Noun'),
#  ('등급', 'Noun'),
#  ('용', 'Noun'),
#  ('설계', 'Noun'),
#  ('본고는', 'Verb'),
#  ('자료', 'Noun'),
#  ('공사', 'Noun'),
#  ('제공', 'Noun'),
#  ('것', 'Noun'),
#  ('연합뉴스', 'Noun'),
#  ('내용', 'Noun'),
#  ('대해', 'Noun'),
#  ('어떠한', 'Adjective'),
#  ('편집', 'Noun'),
#  ('하지', 'Verb'),
#  ('않았', 'Verb'),
#  ('음', 'Noun'),
#  ('밝혀', 'Verb'),
#  ('드립니다', 'Verb'),
#  ('라스베이거스', 'Noun'),
#  ('연합뉴스', 'Noun'),
#  ('이', 'Noun'),
#  ('와이파이', 'Noun'),
#  ('접속', 'Noun'),
#  ('위', 'Noun'),
#  ('최첨단', 'Noun'),
#  ('를', 'Noun'),
#  ('출시', 'Noun'),
#  ('한다고', 'Verb'),
#  ('오늘', 'Noun'),
#  ('발표', 'Noun'),
#  ('했다', 'Verb'),
#  ('은', 'Noun'),
#  ('구현', 'Noun'),
#  ('된', 'Verb'),
#  ('와', 'Verb'),
#  ('빔', 'Noun'),
#  ('형성', 'Noun'),
#  ('기법', 'Noun'),
#  ('통해', 'Noun'),
#  ('첨단', 'Noun'),
#  ('와이파이', 'Noun'),
#  ('기술', 'Noun'),
#  ('대한', 'Noun'),
#  ('집념', 'Noun'),
#  ('다시', 'Noun'),
#  ('한', 'Verb'),
#  ('번', 'Noun'),
#  ('증명', 'Noun'),
#  ('했다', 'Verb'),
#  ('은', 'Noun'),
#  ('가정', 'Noun'),
#  ('커버', 'Noun'),
#  ('리지', 'Noun'),
#  ('엔터프라이즈', 'Noun'),
#  ('등급', 'Noun'),
#  ('보안', 'Noun'),
#  ('측면', 'Noun'),
#  ('더', 'Noun'),
#  ('높은', 'Adjective'),
#  ('성능', 'Noun'),
#  ('낼', 'Noun'),
#  ('수', 'Noun'),
#  ('있도록', 'Adjective'),
#  ('경쟁력', 'Noun'),
#  ('있는', 'Adjective'),
#  ('고급', 'Noun'),
#  ('와이파이', 'Noun'),
#  ('벤치마크', 'Noun'),
#  ('구축', 'Noun'),
#  ('한다', 'Verb'),
#  ('의', 'Noun'),
#  ('와이파이', 'Noun'),
#  ('서비스', 'Noun'),
#  ('품질', 'Noun'),
#  ('기능', 'Noun'),
#  ('낮은', 'Adjective'),
#  ('전력', 'Noun'),
#  ('소비', 'Noun'),
#  ('지원', 'Noun'),
#  ('하도록', 'Verb'),
#  ('설계', 'Noun'),
#  ('돼', 'Verb'),
#  ('단일', 'Noun'),
#  ('사용자', 'Noun'),
#  ('환경', 'Noun'),
#  ('서든', 'Noun'),
#  ('북적', 'Noun'),
#  ('다중', 'Noun'),
#  ('사용자', 'Noun'),
#  ('환경', 'Noun'),
#  ('서든', 'Noun'),
#  ('와', 'Verb'),
#  ('채널', 'Noun'),
#  ('단거리', 'Noun'),
#  ('비롯', 'Noun'),
#  ('해', 'Verb'),
#  ('장거리', 'Noun'),
#  ('최종', 'Noun'),
#  ('사용자', 'Noun'),
#  ('높은', 'Adjective'),
#  ('처리', 'Noun'),
#  ('량', 'Noun'),
#  ('경험', 'Noun'),
#  ('선사', 'Noun'),
#  ('한다', 'Verb'),
#  ('무선', 'Noun'),
#  ('접속', 'Noun'),
#  ('및', 'Noun'),
#  ('네트워킹', 'Noun'),
#  ('책임자', 'Noun'),
#  ('는', 'Verb'),
#  ('자사', 'Noun'),
#  ('최신', 'Noun'),
#  ('와이파이', 'Noun'),
#  ('제품', 'Noun'),
#  ('이', 'Noun'),
#  ('제품', 'Noun'),
#  ('가정', 'Noun'),
#  ('용', 'Noun'),
#  ('라우터', 'Noun'),
#  ('기업', 'Noun'),
#  ('를', 'Noun'),
#  ('위', 'Noun'),
#  ('업계', 'Noun'),
#  ('가장', 'Noun'),
#  ('강력하고', 'Adjective'),
#  ('에너지', 'Noun'),
#  ('효율', 'Noun'),
#  ('라며', 'Noun'),
#  ('또한', 'Noun'),
#  ('모든', 'Noun'),
#  ('소비자', 'Noun'),
#  ('고급', 'Noun'),
#  ('인', 'Noun'),
#  ('클루', 'Noun'),
#  ('시브', 'Noun'),
#  ('기술', 'Noun'),
#  ('제공', 'Noun'),
#  ('하고자', 'Verb'),
#  ('하는', 'Verb'),
#  ('자사', 'Noun'),
#  ('집념', 'Noun'),
#  ('보여주는', 'Verb'),
#  ('좋은', 'Adjective'),
#  ('사례', 'Noun'),
#  ('하다', 'Verb'),
#  ('고', 'Noun'),
#  ('말', 'Noun'),
#  ('했다', 'Verb'),
#  ('은', 'Noun'),
#  ('가정', 'Noun'),
#  ('사무실', 'Noun'),
#  ('환경', 'Noun'),
#  ('영상', 'Noun'),
#  ('고속', 'Noun'),
#  ('데이터', 'Noun'),
#  ('제공', 'Noun'),
#  ('하고자', 'Verb'),
#  ('업계', 'Noun'),
#  ('주도', 'Noun'),
#  ('완전', 'Noun'),
#  ('통합', 'Noun'),
#  ('고성능', 'Noun'),
#  ('이나', 'Noun'),
#  ('외부', 'Noun'),
#  ('사용', 'Noun'),
#  ('또한', 'Noun'),
#  ('빔', 'Noun'),
#  ('형성', 'Noun'),
#  ('첨단', 'Noun'),
#  ('지원', 'Noun'),
#  ('바탕', 'Noun'),
#  ('네', 'Noun'),
#  ('명의', 'Noun'),
#  ('사용자', 'Noun'),
#  ('동시', 'Noun'),
#  ('지원', 'Noun'),
#  ('해', 'Verb'),
#  ('오늘날', 'Noun'),
#  ('무선', 'Noun'),
#  ('환경', 'Noun'),
#  ('스펙트럼', 'Noun'),
#  ('효율', 'Noun'),
#  ('높인다', 'Verb'),
#  ('의', 'Noun'),
#  ('및', 'Noun'),
#  ('로', 'Noun'),
#  ('설계', 'Noun'),
#  ('된', 'Verb'),
#  ('는', 'Verb'),
#  ('서비스', 'Noun'),
#  ('업체', 'Noun'),
#  ('기업', 'Noun'),
#  ('고객', 'Noun'),
#  ('최고', 'Noun'),
#  ('성능', 'Noun'),
#  ('와이파이', 'Noun'),
#  ('경험', 'Noun'),
#  ('제공', 'Noun'),
#  ('하도록', 'Verb'),
#  ('지원', 'Noun'),
#  ('은', 'Noun'),
#  ('과', 'Noun'),
#  ('를', 'Noun'),
#  ('전적', 'Noun'),
#  ('준수', 'Noun'),
#  ('하며', 'Verb'),
#  ('표준', 'Noun'),
#  ('호환', 'Noun'),
#  ('되기', 'Verb'),
#  ('때문', 'Noun'),
#  ('기존', 'Noun'),
#  ('네트워크', 'Noun'),
#  ('크게', 'Noun'),
#  ('개선', 'Noun'),
#  ('시킬', 'Verb'),
#  ('수', 'Noun'),
#  ('있다', 'Adjective'),
#  ('뿐', 'Noun'),
#  ('아니라', 'Adjective'),
#  ('스니퍼', 'Noun'),
#  ('배경', 'Noun'),
#  ('스캔', 'Noun'),
#  ('및', 'Noun'),
#  ('스펙트럼', 'Noun'),
#  ('분석', 'Noun'),
#  ('위해', 'Noun'),
#  ('내장', 'Noun'),
#  ('된', 'Verb'),
#  ('와이파이', 'Noun'),
#  ('바탕', 'Noun'),
#  ('의', 'Noun'),
#  ('강력한', 'Adjective'),
#  ('쿼드코어', 'Noun'),
#  ('기반', 'Noun'),
#  ('네트워크', 'Noun'),
#  ('처리', 'Noun'),
#  ('유닛', 'Noun'),
#  ('결합', 'Noun'),
#  ('또한', 'Noun'),
#  ('스피커', 'Noun'),
#  ('웨어', 'Noun'),
#  ('러블', 'Noun'),
#  ('장치', 'Noun'),
#  ('위해', 'Noun'),
#  ('블루투스', 'Noun'),
#  ('연결', 'Noun'),
#  ('지원', 'Noun'),
#  ('그', 'Noun'),
#  ('결과', 'Noun'),
#  ('최고', 'Noun'),
#  ('품질', 'Noun'),
#  ('자랑', 'Noun'),
#  ('하는', 'Verb'),
#  ('와이파이', 'Noun'),
#  ('경험', 'Noun'),
#  ('위해', 'Noun'),
#  ('최고', 'Noun'),
#  ('접속', 'Noun'),
#  ('솔루션', 'Noun'),
#  ('지원', 'Noun'),
#  ('하는', 'Verb'),
#  ('업계', 'Noun'),
#  ('주도', 'Noun'),
#  ('무선', 'Noun'),
#  ('플랫폼', 'Noun'),
#  ('탄생', 'Noun'),
#  ('한다', 'Verb'),
#  ('뿐', 'Noun'),
#  ('아니라', 'Adjective'),
#  ('은', 'Noun'),
#  ('오늘날', 'Noun'),
#  ('시중', 'Noun'),
#  ('나와', 'Verb'),
#  ('있는', 'Adjective'),
#  ('유사', 'Noun'),
#  ('제품', 'Noun'),
#  ('비교', 'Noun'),
#  ('했을', 'Verb'),
#  ('때', 'Noun'),
#  ('바탕', 'Noun'),
#  ('최소한', 'Noun'),
#  ('전력', 'Noun'),
#  ('소비', 'Noun'),
#  ('한다', 'Verb'),
#  ('은', 'Noun'),
#  ('올', 'Verb'),
#  ('샘플링', 'Noun'),
#  ('진행', 'Noun'),
#  ('양산', 'Noun'),
#  ('착수', 'Noun'),
#  ('할', 'Verb'),
#  ('예정', 'Noun'),
#  ('은', 'Noun'),
#  ('선구', 'Noun'),
#  ('무공', 'Noun'),
#  ('반도체', 'Noun'),
#  ('기업', 'Noun'),
#  ('이자', 'Noun'),
#  ('무선', 'Noun'),
#  ('통신', 'Noun'),
#  ('및', 'Noun'),
#  ('연결', 'Noun'),
#  ('및', 'Noun'),
#  ('블루레이', 'Noun'),
#  ('용', 'Noun'),
#  ('첨단', 'Noun'),
#  ('시장', 'Noun'),
#  ('선도', 'Noun'),
#  ('기업', 'Noun'),
#  ('은', 'Noun'),
#  ('호환', 'Noun'),
#  ('세계', 'Noun'),
#  ('최초', 'Noun'),
#  ('트루', 'Noun'),
#  ('옥타코어', 'Noun'),
#  ('스마트폰', 'Noun'),
#  ('플랫폼', 'Noun'),
#  ('개발', 'Noun'),
#  ('했고', 'Verb'),
#  ('의', 'Noun'),
#  ('기술', 'Noun'),
#  ('멀티코어', 'Noun'),
#  ('모바일', 'Noun'),
#  ('프로세서', 'Noun'),
#  ('풀', 'Noun'),
#  ('파워', 'Noun'),
#  ('사용', 'Noun'),
#  ('가능', 'Noun'),
#  ('케', 'Noun'),
#  ('한다', 'Verb'),
#  ('은', 'Noun'),
#  ('를', 'Noun'),
#  ('통해', 'Noun'),
#  ('자사', 'Noun'),
#  ('제품', 'Noun'),
#  ('중심', 'Noun'),
#  ('하는', 'Verb'),
#  ('장치', 'Noun'),
#  ('제작', 'Noun'),
#  ('애플리케이션', 'Noun'),
#  ('개발', 'Noun'),
#  ('및', 'Noun'),
#  ('서비스', 'Noun'),
#  ('지원', 'Noun'),
#  ('하는', 'Verb'),
#  ('세계', 'Noun'),
#  ('에코', 'Noun'),
#  ('시스템', 'Noun'),
#  ('구축', 'Noun'),
#  ('있다', 'Adjective'),
#  ('선택', 'Noun'),
#  ('된', 'Verb'),
#  ('일부', 'Noun'),
#  ('아닌', 'Adjective'),
#  ('대중', 'Noun'),
#  ('위', 'Noun'),
#  ('인', 'Noun'),
#  ('블링', 'Noun'),
#  ('기술', 'Noun'),
#  ('강조', 'Noun'),
#  ('누구', 'Noun'),
#  ('가', 'Verb'),
#  ('될', 'Verb'),
#  ('수', 'Noun'),
#  ('있다', 'Adjective'),
#  ('은', 'Noun'),
#  ('대만', 'Noun'),
#  ('본사', 'Noun'),
#  ('전', 'Noun'),
#  ('세계', 'Noun'),
#  ('곳곳', 'Noun'),
#  ('지사', 'Noun'),
#  ('두고', 'Verb'),
#  ('있다', 'Adjective'),
#  ('추가', 'Noun'),
#  ('정보', 'Noun'),
#  ('웹사이트', 'Noun'),
#  ('참조', 'Noun'),
#  ('한다', 'Verb'),
#  ('홍보', 'Noun'),
#  ('부', 'Noun'),
#  ('출처', 'Noun')]

# %%
result = []        #불용어 제거
for w in result_word:
    if w[0] not in vocab:
        result.append(w)

print(result)
# Out:
# [('지원', 'Noun'), ('하는', 'Verb'), ('칩셋', 'Noun'), ('고급', 'Noun'), ('홈', 'Noun'), ('게이트웨이', 'Noun'), ('셋톱박스', 'Noun'), ('비디오', 'Noun'), ('브리지', 'Noun'), ('라우터', 'Noun'), ('엔터프라이즈', 'Noun'), ('등급', 'Noun'), ('용', 'Noun'), ('설계', 'Noun'), ('본고는', 'Verb'), ('자료', 'Noun'), ('공사', 'Noun'), ('제공', 'Noun'), ('연합뉴스', 'Noun'), ('내용', 'Noun'), ('대해', 'Noun'), ('편집', 'Noun'), ('하지', 'Verb'), ('않았', 'Verb'), ('음', 'Noun'), ('밝혀', 'Verb'), ('드립니다', 'Verb'), ('라스베이거스', 'Noun'), ('연합뉴스', 'Noun'), ('와이파이', 'Noun'), ('접속', 'Noun'), ('위', 'Noun'), ('최첨단', 'Noun'), ('출시', 'Noun'), ('한다고', 'Verb'), ('오늘', 'Noun'), ('발표', 'Noun'), ('했다', 'Verb'), ('은', 'Noun'), ('구현', 'Noun'), ('된', 'Verb'), ('빔', 'Noun'), ('형성', 'Noun'), ('기법', 'Noun'), ('통해', 'Noun'), ('첨단', 'Noun'), ('와이파이', 'Noun'), ('기술', 'Noun'), ('대한', 'Noun'), ('집념', 'Noun'), ('다시', 'Noun'), ('한', 'Verb'), ('번', 'Noun'), ('증명', 'Noun'), ('했다', 'Verb'), ('은', 'Noun'), ('가정', 'Noun'), ('커버', 'Noun'), ('리지', 'Noun'), ('엔터프라이즈', 'Noun'), ('등급', 'Noun'), ('보안', 'Noun'), ('측면', 'Noun'), ('더', 'Noun'), ('높은', 'Adjective'), ('성능', 'Noun'), ('낼', 'Noun'), ('수', 'Noun'), ('있도록', 'Adjective'), ('경쟁력', 'Noun'), ('있는', 'Adjective'), ('고급', 'Noun'), ('와이파이', 'Noun'), ('벤치마크', 'Noun'), ('구축', 'Noun'), ('한다', 'Verb'), ('와이파이', 'Noun'), ('서비스', 'Noun'), ('품질', 'Noun'), ('기능', 'Noun'), ('낮은', 'Adjective'), ('전력', 'Noun'), ('소비', 'Noun'), ('지원', 'Noun'), ('하도록', 'Verb'), ('설계', 'Noun'), ('돼', 'Verb'), ('단일', 'Noun'), ('사용자', 'Noun'), ('환경', 'Noun'), ('서든', 'Noun'), ('북적', 'Noun'), ('다중', 'Noun'), ('사용자', 'Noun'), ('환경', 'Noun'), ('서든', 'Noun'), ('채널', 'Noun'), ('단거리', 'Noun'), ('비롯', 'Noun'), ('해', 'Verb'), ('장거리', 'Noun'), ('최종', 'Noun'), ('사용자', 'Noun'), ('높은', 'Adjective'), ('처리', 'Noun'), ('량', 'Noun'), ('경험', 'Noun'), ('선사', 'Noun'), ('한다', 'Verb'), ('무선', 'Noun'), ('접속', 'Noun'), ('네트워킹', 'Noun'), ('책임자', 'Noun'), ('는', 'Verb'), ('자사', 'Noun'), ('최신', 'Noun'), ('와이파이', 'Noun'), ('제품', 'Noun'), ('제품', 'Noun'), ('가정', 'Noun'), ('용', 'Noun'), ('라우터', 'Noun'), ('기업', 'Noun'), ('위', 'Noun'), ('업계', 'Noun'), ('가장', 'Noun'), ('강력하고', 'Adjective'), ('에너지', 'Noun'), ('효율', 'Noun'), ('라며', 'Noun'), ('모든', 'Noun'), ('소비자', 'Noun'), ('고급', 'Noun'), ('인', 'Noun'), ('클루', 'Noun'), ('시브', 'Noun'), ('기술', 'Noun'), ('제공', 'Noun'), ('하고자', 'Verb'), ('하는', 'Verb'), ('자사', 'Noun'), ('집념', 'Noun'), ('보여주는', 'Verb'), ('좋은', 'Adjective'), ('사례', 'Noun'), ('하다', 'Verb'), ('고', 'Noun'), ('말', 'Noun'), ('했다', 'Verb'), ('은', 'Noun'), ('가정', 'Noun'), ('사무실', 'Noun'), ('환경', 'Noun'), ('영상', 'Noun'), ('고속', 'Noun'), ('데이터', 'Noun'), ('제공', 'Noun'), ('하고자', 'Verb'), ('업계', 'Noun'), ('주도', 'Noun'), ('완전', 'Noun'), ('통합', 'Noun'), ('고성능', 'Noun'), ('이나', 'Noun'), ('외부', 'Noun'), ('사용', 'Noun'), ('빔', 'Noun'), ('형성', 'Noun'), ('첨단', 'Noun'), ('지원', 'Noun'), ('바탕', 'Noun'), ('명의', 'Noun'), ('사용자', 'Noun'), ('동시', 'Noun'), ('지원', 'Noun'), ('해', 'Verb'), ('오늘날', 'Noun'), ('무선', 'Noun'), ('환경', 'Noun'), ('스펙트럼', 'Noun'), ('효율', 'Noun'), ('높인다', 'Verb'), ('설계', 'Noun'), ('된', 'Verb'), ('는', 'Verb'), ('서비스', 'Noun'), ('업체', 'Noun'), ('기업', 'Noun'), ('고객', 'Noun'), ('최고', 'Noun'), ('성능', 'Noun'), ('와이파이', 'Noun'), ('경험', 'Noun'), ('제공', 'Noun'), ('하도록', 'Verb'), ('지원', 'Noun'), ('은', 'Noun'), ('전적', 'Noun'), ('준수', 'Noun'), ('하며', 'Verb'), ('표준', 'Noun'), ('호환', 'Noun'), ('되기', 'Verb'), ('때문', 'Noun'), ('기존', 'Noun'), ('네트워크', 'Noun'), ('크게', 'Noun'), ('개선', 'Noun'), ('시킬', 'Verb'), ('수', 'Noun'), ('뿐', 'Noun'), ('아니라', 'Adjective'), ('스니퍼', 'Noun'), ('배경', 'Noun'), ('스캔', 'Noun'), ('스펙트럼', 'Noun'), ('분석', 'Noun'), ('위해', 'Noun'), ('내장', 'Noun'), ('된', 'Verb'), ('와이파이', 'Noun'), ('바탕', 'Noun'), ('강력한', 'Adjective'), ('쿼드코어', 'Noun'), ('기반', 'Noun'), ('네트워크', 'Noun'), ('처리', 'Noun'), ('유닛', 'Noun'), ('결합', 'Noun'), ('스피커', 'Noun'), ('웨어', 'Noun'), ('러블', 'Noun'), ('장치', 'Noun'), ('위해', 'Noun'), ('블루투스', 'Noun'), ('연결', 'Noun'), ('지원', 'Noun'), ('결과', 'Noun'), ('최고', 'Noun'), ('품질', 'Noun'), ('자랑', 'Noun'), ('하는', 'Verb'), ('와이파이', 'Noun'), ('경험' ...

# %%
result
# Out:
# [('지원', 'Noun'),
#  ('하는', 'Verb'),
#  ('칩셋', 'Noun'),
#  ('고급', 'Noun'),
#  ('홈', 'Noun'),
#  ('게이트웨이', 'Noun'),
#  ('셋톱박스', 'Noun'),
#  ('비디오', 'Noun'),
#  ('브리지', 'Noun'),
#  ('라우터', 'Noun'),
#  ('엔터프라이즈', 'Noun'),
#  ('등급', 'Noun'),
#  ('용', 'Noun'),
#  ('설계', 'Noun'),
#  ('본고는', 'Verb'),
#  ('자료', 'Noun'),
#  ('공사', 'Noun'),
#  ('제공', 'Noun'),
#  ('연합뉴스', 'Noun'),
#  ('내용', 'Noun'),
#  ('대해', 'Noun'),
#  ('편집', 'Noun'),
#  ('하지', 'Verb'),
#  ('않았', 'Verb'),
#  ('음', 'Noun'),
#  ('밝혀', 'Verb'),
#  ('드립니다', 'Verb'),
#  ('라스베이거스', 'Noun'),
#  ('연합뉴스', 'Noun'),
#  ('와이파이', 'Noun'),
#  ('접속', 'Noun'),
#  ('위', 'Noun'),
#  ('최첨단', 'Noun'),
#  ('출시', 'Noun'),
#  ('한다고', 'Verb'),
#  ('오늘', 'Noun'),
#  ('발표', 'Noun'),
#  ('했다', 'Verb'),
#  ('은', 'Noun'),
#  ('구현', 'Noun'),
#  ('된', 'Verb'),
#  ('빔', 'Noun'),
#  ('형성', 'Noun'),
#  ('기법', 'Noun'),
#  ('통해', 'Noun'),
#  ('첨단', 'Noun'),
#  ('와이파이', 'Noun'),
#  ('기술', 'Noun'),
#  ('대한', 'Noun'),
#  ('집념', 'Noun'),
#  ('다시', 'Noun'),
#  ('한', 'Verb'),
#  ('번', 'Noun'),
#  ('증명', 'Noun'),
#  ('했다', 'Verb'),
#  ('은', 'Noun'),
#  ('가정', 'Noun'),
#  ('커버', 'Noun'),
#  ('리지', 'Noun'),
#  ('엔터프라이즈', 'Noun'),
#  ('등급', 'Noun'),
#  ('보안', 'Noun'),
#  ('측면', 'Noun'),
#  ('더', 'Noun'),
#  ('높은', 'Adjective'),
#  ('성능', 'Noun'),
#  ('낼', 'Noun'),
#  ('수', 'Noun'),
#  ('있도록', 'Adjective'),
#  ('경쟁력', 'Noun'),
#  ('있는', 'Adjective'),
#  ('고급', 'Noun'),
#  ('와이파이', 'Noun'),
#  ('벤치마크', 'Noun'),
#  ('구축', 'Noun'),
#  ('한다', 'Verb'),
#  ('와이파이', 'Noun'),
#  ('서비스', 'Noun'),
#  ('품질', 'Noun'),
#  ('기능', 'Noun'),
#  ('낮은', 'Adjective'),
#  ('전력', 'Noun'),
#  ('소비', 'Noun'),
#  ('지원', 'Noun'),
#  ('하도록', 'Verb'),
#  ('설계', 'Noun'),
#  ('돼', 'Verb'),
#  ('단일', 'Noun'),
#  ('사용자', 'Noun'),
#  ('환경', 'Noun'),
#  ('서든', 'Noun'),
#  ('북적', 'Noun'),
#  ('다중', 'Noun'),
#  ('사용자', 'Noun'),
#  ('환경', 'Noun'),
#  ('서든', 'Noun'),
#  ('채널', 'Noun'),
#  ('단거리', 'Noun'),
#  ('비롯', 'Noun'),
#  ('해', 'Verb'),
#  ('장거리', 'Noun'),
#  ('최종', 'Noun'),
#  ('사용자', 'Noun'),
#  ('높은', 'Adjective'),
#  ('처리', 'Noun'),
#  ('량', 'Noun'),
#  ('경험', 'Noun'),
#  ('선사', 'Noun'),
#  ('한다', 'Verb'),
#  ('무선', 'Noun'),
#  ('접속', 'Noun'),
#  ('네트워킹', 'Noun'),
#  ('책임자', 'Noun'),
#  ('는', 'Verb'),
#  ('자사', 'Noun'),
#  ('최신', 'Noun'),
#  ('와이파이', 'Noun'),
#  ('제품', 'Noun'),
#  ('제품', 'Noun'),
#  ('가정', 'Noun'),
#  ('용', 'Noun'),
#  ('라우터', 'Noun'),
#  ('기업', 'Noun'),
#  ('위', 'Noun'),
#  ('업계', 'Noun'),
#  ('가장', 'Noun'),
#  ('강력하고', 'Adjective'),
#  ('에너지', 'Noun'),
#  ('효율', 'Noun'),
#  ('라며', 'Noun'),
#  ('모든', 'Noun'),
#  ('소비자', 'Noun'),
#  ('고급', 'Noun'),
#  ('인', 'Noun'),
#  ('클루', 'Noun'),
#  ('시브', 'Noun'),
#  ('기술', 'Noun'),
#  ('제공', 'Noun'),
#  ('하고자', 'Verb'),
#  ('하는', 'Verb'),
#  ('자사', 'Noun'),
#  ('집념', 'Noun'),
#  ('보여주는', 'Verb'),
#  ('좋은', 'Adjective'),
#  ('사례', 'Noun'),
#  ('하다', 'Verb'),
#  ('고', 'Noun'),
#  ('말', 'Noun'),
#  ('했다', 'Verb'),
#  ('은', 'Noun'),
#  ('가정', 'Noun'),
#  ('사무실', 'Noun'),
#  ('환경', 'Noun'),
#  ('영상', 'Noun'),
#  ('고속', 'Noun'),
#  ('데이터', 'Noun'),
#  ('제공', 'Noun'),
#  ('하고자', 'Verb'),
#  ('업계', 'Noun'),
#  ('주도', 'Noun'),
#  ('완전', 'Noun'),
#  ('통합', 'Noun'),
#  ('고성능', 'Noun'),
#  ('이나', 'Noun'),
#  ('외부', 'Noun'),
#  ('사용', 'Noun'),
#  ('빔', 'Noun'),
#  ('형성', 'Noun'),
#  ('첨단', 'Noun'),
#  ('지원', 'Noun'),
#  ('바탕', 'Noun'),
#  ('명의', 'Noun'),
#  ('사용자', 'Noun'),
#  ('동시', 'Noun'),
#  ('지원', 'Noun'),
#  ('해', 'Verb'),
#  ('오늘날', 'Noun'),
#  ('무선', 'Noun'),
#  ('환경', 'Noun'),
#  ('스펙트럼', 'Noun'),
#  ('효율', 'Noun'),
#  ('높인다', 'Verb'),
#  ('설계', 'Noun'),
#  ('된', 'Verb'),
#  ('는', 'Verb'),
#  ('서비스', 'Noun'),
#  ('업체', 'Noun'),
#  ('기업', 'Noun'),
#  ('고객', 'Noun'),
#  ('최고', 'Noun'),
#  ('성능', 'Noun'),
#  ('와이파이', 'Noun'),
#  ('경험', 'Noun'),
#  ('제공', 'Noun'),
#  ('하도록', 'Verb'),
#  ('지원', 'Noun'),
#  ('은', 'Noun'),
#  ('전적', 'Noun'),
#  ('준수', 'Noun'),
#  ('하며', 'Verb'),
#  ('표준', 'Noun'),
#  ('호환', 'Noun'),
#  ('되기', 'Verb'),
#  ('때문', 'Noun'),
#  ('기존', 'Noun'),
#  ('네트워크', 'Noun'),
#  ('크게', 'Noun'),
#  ('개선', 'Noun'),
#  ('시킬', 'Verb'),
#  ('수', 'Noun'),
#  ('뿐', 'Noun'),
#  ('아니라', 'Adjective'),
#  ('스니퍼', 'Noun'),
#  ('배경', 'Noun'),
#  ('스캔', 'Noun'),
#  ('스펙트럼', 'Noun'),
#  ('분석', 'Noun'),
#  ('위해', 'Noun'),
#  ('내장', 'Noun'),
#  ('된', 'Verb'),
#  ('와이파이', 'Noun'),
#  ('바탕', 'Noun'),
#  ('강력한', 'Adjective'),
#  ('쿼드코어', 'Noun'),
#  ('기반', 'Noun'),
#  ('네트워크', 'Noun'),
#  ('처리', 'Noun'),
#  ('유닛', 'Noun'),
#  ('결합', 'Noun'),
#  ('스피커', 'Noun'),
#  ('웨어', 'Noun'),
#  ('러블', 'Noun'),
#  ('장치', 'Noun'),
#  ('위해', 'Noun'),
#  ('블루투스', 'Noun'),
#  ('연결', 'Noun'),
#  ('지원', 'Noun'),
#  ('결과', 'Noun'),
#  ('최고', 'Noun'),
#  ('품질', 'Noun'),
#  ('자랑', 'Noun'),
#  ('하는', 'Verb'),
#  ('와이파이', 'Noun'),
#  ('경험', 'Noun'),
#  ('위해', 'Noun'),
#  ('최고', 'Noun'),
#  ('접속', 'Noun'),
#  ('솔루션', 'Noun'),
#  ('지원', 'Noun'),
#  ('하는', 'Verb'),
#  ('업계', 'Noun'),
#  ('주도', 'Noun'),
#  ('무선', 'Noun'),
#  ('플랫폼', 'Noun'),
#  ('탄생', 'Noun'),
#  ('한다', 'Verb'),
#  ('뿐', 'Noun'),
#  ('아니라', 'Adjective'),
#  ('은', 'Noun'),
#  ('오늘날', 'Noun'),
#  ('시중', 'Noun'),
#  ('나와', 'Verb'),
#  ('있는', 'Adjective'),
#  ('유사', 'Noun'),
#  ('제품', 'Noun'),
#  ('비교', 'Noun'),
#  ('했을', 'Verb'),
#  ('바탕', 'Noun'),
#  ('최소한', 'Noun'),
#  ('전력', 'Noun'),
#  ('소비', 'Noun'),
#  ('한다', 'Verb'),
#  ('은', 'Noun'),
#  ('올', 'Verb'),
#  ('샘플링', 'Noun'),
#  ('진행', 'Noun'),
#  ('양산', 'Noun'),
#  ('착수', 'Noun'),
#  ('할', 'Verb'),
#  ('예정', 'Noun'),
#  ('은', 'Noun'),
#  ('선구', 'Noun'),
#  ('무공', 'Noun'),
#  ('반도체', 'Noun'),
#  ('기업', 'Noun'),
#  ('이자', 'Noun'),
#  ('무선', 'Noun'),
#  ('통신', 'Noun'),
#  ('연결', 'Noun'),
#  ('블루레이', 'Noun'),
#  ('용', 'Noun'),
#  ('첨단', 'Noun'),
#  ('시장', 'Noun'),
#  ('선도', 'Noun'),
#  ('기업', 'Noun'),
#  ('은', 'Noun'),
#  ('호환', 'Noun'),
#  ('세계', 'Noun'),
#  ('최초', 'Noun'),
#  ('트루', 'Noun'),
#  ('옥타코어', 'Noun'),
#  ('스마트폰', 'Noun'),
#  ('플랫폼', 'Noun'),
#  ('개발', 'Noun'),
#  ('했고', 'Verb'),
#  ('기술', 'Noun'),
#  ('멀티코어', 'Noun'),
#  ('모바일', 'Noun'),
#  ('프로세서', 'Noun'),
#  ('풀', 'Noun'),
#  ('파워', 'Noun'),
#  ('사용', 'Noun'),
#  ('가능', 'Noun'),
#  ('케', 'Noun'),
#  ('한다', 'Verb'),
#  ('은', 'Noun'),
#  ('통해', 'Noun'),
#  ('자사', 'Noun'),
#  ('제품', 'Noun'),
#  ('중심', 'Noun'),
#  ('하는', 'Verb'),
#  ('장치', 'Noun'),
#  ('제작', 'Noun'),
#  ('애플리케이션', 'Noun'),
#  ('개발', 'Noun'),
#  ('서비스', 'Noun'),
#  ('지원', 'Noun'),
#  ('하는', 'Verb'),
#  ('세계', 'Noun'),
#  ('에코', 'Noun'),
#  ('시스템', 'Noun'),
#  ('구축', 'Noun'),
#  ('선택', 'Noun'),
#  ('된', 'Verb'),
#  ('일부', 'Noun'),
#  ('아닌', 'Adjective'),
#  ('대중', 'Noun'),
#  ('위', 'Noun'),
#  ('인', 'Noun'),
#  ('블링', 'Noun'),
#  ('기술', 'Noun'),
#  ('강조', 'Noun'),
#  ('될', 'Verb'),
#  ('수', 'Noun'),
#  ('은', 'Noun'),
#  ('대만', 'Noun'),
#  ('본사', 'Noun'),
#  ('전', 'Noun'),
#  ('세계', 'Noun'),
#  ('곳곳', 'Noun'),
#  ('지사', 'Noun'),
#  ('두고', 'Verb'),
#  ('추가', 'Noun'),
#  ('정보', 'Noun'),
#  ('웹사이트', 'Noun'),
#  ('참조', 'Noun'),
#  ('한다', 'Verb'),
#  ('홍보', 'Noun'),
#  ('부', 'Noun'),
#  ('출처', 'Noun')]

# %%
result_pick = [i[0] for i in result]     #사용할 단어들만 추출

# %%
result_pick
# Out:
# ['지원',
#  '하는',
#  '칩셋',
#  '고급',
#  '홈',
#  '게이트웨이',
#  '셋톱박스',
#  '비디오',
#  '브리지',
#  '라우터',
#  '엔터프라이즈',
#  '등급',
#  '용',
#  '설계',
#  '본고는',
#  '자료',
#  '공사',
#  '제공',
#  '연합뉴스',
#  '내용',
#  '대해',
#  '편집',
#  '하지',
#  '않았',
#  '음',
#  '밝혀',
#  '드립니다',
#  '라스베이거스',
#  '연합뉴스',
#  '와이파이',
#  '접속',
#  '위',
#  '최첨단',
#  '출시',
#  '한다고',
#  '오늘',
#  '발표',
#  '했다',
#  '은',
#  '구현',
#  '된',
#  '빔',
#  '형성',
#  '기법',
#  '통해',
#  '첨단',
#  '와이파이',
#  '기술',
#  '대한',
#  '집념',
#  '다시',
#  '한',
#  '번',
#  '증명',
#  '했다',
#  '은',
#  '가정',
#  '커버',
#  '리지',
#  '엔터프라이즈',
#  '등급',
#  '보안',
#  '측면',
#  '더',
#  '높은',
#  '성능',
#  '낼',
#  '수',
#  '있도록',
#  '경쟁력',
#  '있는',
#  '고급',
#  '와이파이',
#  '벤치마크',
#  '구축',
#  '한다',
#  '와이파이',
#  '서비스',
#  '품질',
#  '기능',
#  '낮은',
#  '전력',
#  '소비',
#  '지원',
#  '하도록',
#  '설계',
#  '돼',
#  '단일',
#  '사용자',
#  '환경',
#  '서든',
#  '북적',
#  '다중',
#  '사용자',
#  '환경',
#  '서든',
#  '채널',
#  '단거리',
#  '비롯',
#  '해',
#  '장거리',
#  '최종',
#  '사용자',
#  '높은',
#  '처리',
#  '량',
#  '경험',
#  '선사',
#  '한다',
#  '무선',
#  '접속',
#  '네트워킹',
#  '책임자',
#  '는',
#  '자사',
#  '최신',
#  '와이파이',
#  '제품',
#  '제품',
#  '가정',
#  '용',
#  '라우터',
#  '기업',
#  '위',
#  '업계',
#  '가장',
#  '강력하고',
#  '에너지',
#  '효율',
#  '라며',
#  '모든',
#  '소비자',
#  '고급',
#  '인',
#  '클루',
#  '시브',
#  '기술',
#  '제공',
#  '하고자',
#  '하는',
#  '자사',
#  '집념',
#  '보여주는',
#  '좋은',
#  '사례',
#  '하다',
#  '고',
#  '말',
#  '했다',
#  '은',
#  '가정',
#  '사무실',
#  '환경',
#  '영상',
#  '고속',
#  '데이터',
#  '제공',
#  '하고자',
#  '업계',
#  '주도',
#  '완전',
#  '통합',
#  '고성능',
#  '이나',
#  '외부',
#  '사용',
#  '빔',
#  '형성',
#  '첨단',
#  '지원',
#  '바탕',
#  '명의',
#  '사용자',
#  '동시',
#  '지원',
#  '해',
#  '오늘날',
#  '무선',
#  '환경',
#  '스펙트럼',
#  '효율',
#  '높인다',
#  '설계',
#  '된',
#  '는',
#  '서비스',
#  '업체',
#  '기업',
#  '고객',
#  '최고',
#  '성능',
#  '와이파이',
#  '경험',
#  '제공',
#  '하도록',
#  '지원',
#  '은',
#  '전적',
#  '준수',
#  '하며',
#  '표준',
#  '호환',
#  '되기',
#  '때문',
#  '기존',
#  '네트워크',
#  '크게',
#  '개선',
#  '시킬',
#  '수',
#  '뿐',
#  '아니라',
#  '스니퍼',
#  '배경',
#  '스캔',
#  '스펙트럼',
#  '분석',
#  '위해',
#  '내장',
#  '된',
#  '와이파이',
#  '바탕',
#  '강력한',
#  '쿼드코어',
#  '기반',
#  '네트워크',
#  '처리',
#  '유닛',
#  '결합',
#  '스피커',
#  '웨어',
#  '러블',
#  '장치',
#  '위해',
#  '블루투스',
#  '연결',
#  '지원',
#  '결과',
#  '최고',
#  '품질',
#  '자랑',
#  '하는',
#  '와이파이',
#  '경험',
#  '위해',
#  '최고',
#  '접속',
#  '솔루션',
#  '지원',
#  '하는',
#  '업계',
#  '주도',
#  '무선',
#  '플랫폼',
#  '탄생',
#  '한다',
#  '뿐',
#  '아니라',
#  '은',
#  '오늘날',
#  '시중',
#  '나와',
#  '있는',
#  '유사',
#  '제품',
#  '비교',
#  '했을',
#  '바탕',
#  '최소한',
#  '전력',
#  '소비',
#  '한다',
#  '은',
#  '올',
#  '샘플링',
#  '진행',
#  '양산',
#  '착수',
#  '할',
#  '예정',
#  '은',
#  '선구',
#  '무공',
#  '반도체',
#  '기업',
#  '이자',
#  '무선',
#  '통신',
#  '연결',
#  '블루레이',
#  '용',
#  '첨단',
#  '시장',
#  '선도',
#  '기업',
#  '은',
#  '호환',
#  '세계',
#  '최초',
#  '트루',
#  '옥타코어',
#  '스마트폰',
#  '플랫폼',
#  '개발',
#  '했고',
#  '기술',
#  '멀티코어',
#  '모바일',
#  '프로세서',
#  '풀',
#  '파워',
#  '사용',
#  '가능',
#  '케',
#  '한다',
#  '은',
#  '통해',
#  '자사',
#  '제품',
#  '중심',
#  '하는',
#  '장치',
#  '제작',
#  '애플리케이션',
#  '개발',
#  '서비스',
#  '지원',
#  '하는',
#  '세계',
#  '에코',
#  '시스템',
#  '구축',
#  '선택',
#  '된',
#  '일부',
#  '아닌',
#  '대중',
#  '위',
#  '인',
#  '블링',
#  '기술',
#  '강조',
#  '될',
#  '수',
#  '은',
#  '대만',
#  '본사',
#  '전',
#  '세계',
#  '곳곳',
#  '지사',
#  '두고',
#  '추가',
#  '정보',
#  '웹사이트',
#  '참조',
#  '한다',
#  '홍보',
#  '부',
#  '출처']

# %%
dictionary = Dictionary(result)

# %%
print(dictionary.token2id)           #단어들에 id 부여
# Out:
# {'Noun': 0, '지원': 1, 'Verb': 2, '하는': 3, '칩셋': 4, '고급': 5, '홈': 6, '게이트웨이': 7, '셋톱박스': 8, '비디오': 9, '브리지': 10, '라우터': 11, '엔터프라이즈': 12, '등급': 13, '용': 14, '설계': 15, '본고는': 16, '자료': 17, '공사': 18, '제공': 19, '연합뉴스': 20, '내용': 21, '대해': 22, '편집': 23, '하지': 24, '않았': 25, '음': 26, '밝혀': 27, '드립니다': 28, '라스베이거스': 29, '와이파이': 30, '접속': 31, '위': 32, '최첨단': 33, '출시': 34, '한다고': 35, '오늘': 36, '발표': 37, '했다': 38, '은': 39, '구현': 40, '된': 41, '빔': 42, '형성': 43, '기법': 44, '통해': 45, '첨단': 46, '기술': 47, '대한': 48, '집념': 49, '다시': 50, '한': 51, '번': 52, '증명': 53, '가정': 54, '커버': 55, '리지': 56, '보안': 57, '측면': 58, '더': 59, 'Adjective': 60, '높은': 61, '성능': 62, '낼': 63, '수': 64, '있도록': 65, '경쟁력': 66, '있는': 67, '벤치마크': 68, '구축': 69, '한다': 70, '서비스': 71, '품질': 72, '기능': 73, '낮은': 74, '전력': 75, '소비': 76, '하도록': 77, '돼': 78, '단일': 79, '사용자': 80, '환경': 81, '서든': 82, '북적': 83, '다중': 84, '채널': 85, '단거리': 86, '비롯': 87, '해': 88, '장거리': 89, '최종': 90, '처리': 91, '량': 92, '경험': 93, '선사': 94, '무선': 95, '네트워킹': 96, '책임자': 97, '는': 98, '자사': 99, '최신': 100, '제품': 101, '기업': 102, '업계': 103, '가장': 104, '강력하고': 105, '에너지': 106, '효율': 107, '라며': 108, '모든': 109, '소비자': 110, '인': 111, '클루': 112, '시브': 113, '하고자': 114, '보여주는': 115, '좋은': 116, '사례': 117, '하다': 118, '고': 119, '말': 120, '사무실': 121, '영상': 122, '고속': 123, '데이터': 124, '주도': 125, '완전': 126, '통합': 127, '고성능': 128, '이나': 129, '외부': 130, '사용': 131, '바탕': 132, '명의': 133, '동시': 134, '오늘날': 135, '스펙트럼': 136, '높인다': 137, '업체': 138, '고객': 139, '최고': 140, '전적': 141, '준수': 142, '하며': 143, '표준': 144, '호환': 145, '되기': 146, '때문': 147, '기존': 148, '네트워크': 149, '크게': 150, '개선': 151, '시킬': 152, '뿐': 153, '아니라': 154, '스니퍼': 155, '배경': 156, '스캔': 157, '분석': 158, '위해': 159, '내장': 160, '강력한': 161, '쿼드코어': 162, '기반': 163, '유닛': 164, '결합': 165, '스피커': 166, '웨어': 167, '러블': 168, '장치': 169, '블루투스': 170, '연결': 171, '결과': 172, '자랑': 173, '솔루션': 174, '플랫폼': 175, '탄생': 176, '시중': 177, '나와': 178, '유사': 179, '비교': 180, '했을': 181, '최소한': 182, '올': 183, '샘플링': 184, '진행': 185, '양산': 186, '착수': 187, '할': 188, '예정': 189, '선구': 190, '무공': 191, '반도체': 192, '이자': 193, '통신': 194, '블루레이': 195, '시장': 196, '선도': 197, '세계': 198, '최초': 199, '트루': 200, '옥타코어': 201, '스마트폰': 202, '개발': 203, '했고': 204, '멀티코어': 205, '모바일': 206, '프로세서': 207, '풀': 208, '파워': 209, '가능': 210, '케': 211, '중심': 212, '제작': 213, '애플리케이션': 214, '에코': 215, '시스템': 216, '선택': 217, '일부': 218, '아닌': 219, '대중': 220, '블링': 221, '강조': 222, '될': 223, '대만': 224, '본사': 225, '전': 226, '곳곳': 227, '지사': 228, '두고': 229, '추가': 230, '정보': 231, '웹사이트': 232, '참조': 233, '홍보': 234, '부': 235, '출처': 236}

# %%
corpus = [dictionary.doc2bow(result_pick) for result_pick in result]

# %%
dictionary[0]
# Out:
# 'Noun'

# %%
del dictionary['Noun']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-154-9bce0432c43c> in <module>
# ----> 1 del dictionary['Noun']
#
# TypeError: 'Dictionary' object does not support item deletion

# %%
len(dictionary)   # 출력된 수의 단어가 학습
# Out:
# 237

# %%
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = 10, id2word=dictionary, passes=15)

# %%
topics = ldamodel.print_topics(num_words=10)

# %%
for topic in topics:
    print(topic)
# Out:
# (0, '0.171*"Verb" + 0.171*"Noun" + 0.040*"수" + 0.040*"업계" + 0.040*"했다" + 0.027*"플랫폼" + 0.027*"해" + 0.027*"는" + 0.027*"하도록" + 0.014*"낼"')
# (1, '0.245*"Verb" + 0.129*"Noun" + 0.065*"하는" + 0.065*"한다" + 0.033*"용" + 0.022*"서든" + 0.022*"네트워크" + 0.022*"높은" + 0.012*"보여주는" + 0.012*"할"')
# (2, '0.390*"Noun" + 0.027*"위" + 0.027*"고급" + 0.027*"서비스" + 0.027*"접속" + 0.027*"최고" + 0.018*"구축" + 0.018*"통해" + 0.018*"처리" + 0.018*"스펙트럼"')
# (3, '0.439*"Noun" + 0.044*"지원" + 0.022*"기술" + 0.022*"제공" + 0.022*"제품" + 0.017*"가정" + 0.017*"자사" + 0.017*"첨단" + 0.011*"효율" + 0.011*"엔터프라이즈"')
# (4, '0.191*"Verb" + 0.096*"된" + 0.026*"하며" + 0.026*"한" + 0.026*"하지" + 0.026*"한다고" + 0.026*"증명" + 0.026*"유닛" + 0.026*"있도록" + 0.003*"Adjective"')
# (5, '0.199*"Adjective" + 0.092*"Verb" + 0.047*"하고자" + 0.047*"아니라" + 0.025*"나와" + 0.025*"올" + 0.025*"아닌" + 0.025*"제작" + 0.002*"Noun" + 0.002*"한다"')
# (6, '0.446*"Noun" + 0.050*"은" + 0.040*"와이파이" + 0.020*"사용자" + 0.020*"기업" + 0.020*"환경" + 0.015*"설계" + 0.010*"주도" + 0.010*"라우터" + 0.010*"뿐"')
# (7, '0.253*"Noun" + 0.069*"무선" + 0.052*"Adjective" + 0.035*"있는" + 0.035*"품질" + 0.035*"형성" + 0.035*"연합뉴스" + 0.018*"고객" + 0.018*"음" + 0.018*"솔루션"')
# (8, '0.248*"Noun" + 0.064*"경험" + 0.064*"위해" + 0.043*"장치" + 0.023*"대만" + 0.023*"중심" + 0.023*"샘플링" + 0.023*"이나" + 0.023*"하다" + 0.002*"제품"')
# (9, '0.362*"Noun" + 0.035*"바탕" + 0.035*"세계" + 0.024*"개발" + 0.024*"집념" + 0.024*"호환" + 0.012*"가능" + 0.012*"기법" + 0.012*"대해" + 0.012*"량"')
