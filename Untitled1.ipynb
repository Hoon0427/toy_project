# %%
import pandas as pd
import numpy as np

# %%
dta = pd.read_excel('/home/ekim_reverse/PyCode/study/Python.study/toy_project/online_news_D1_re.xlsx')

# %%
dta.head()
# Out:
#         Date    topic0    topic1    topic2    topic3    topic4        topic5  \
# 0 2015-01-01 -0.000040 -0.000027 -0.000046 -0.000059 -0.000049 -4.951829e-06
# 1 2015-01-02 -0.000006 -0.000007 -0.000010 -0.000011 -0.000017 -9.154635e-07
# 2 2015-01-03  0.000046  0.000044  0.000053  0.000051  0.000062  1.062383e-05
# 3 2015-01-04 -0.000099 -0.000150 -0.000116 -0.000106 -0.000208 -4.820419e-05
# 4 2015-01-05  0.000163  0.000161  0.000159  0.000214  0.000290  4.499154e-05
#
#          topic6    topic7    topic8  ...       topic10   topic11   topic12  \
# 0 -7.097621e-06 -0.000043 -0.000064  ... -3.466280e-06 -0.000021 -0.000022
# 1 -3.923415e-07 -0.000005 -0.000012  ... -2.615610e-07 -0.000004 -0.000006
# 2  1.239447e-05  0.000039  0.000078  ...  0.000000e+00  0.000048  0.000025
# 3 -4.686519e-06 -0.000029 -0.000159  ... -5.356021e-06 -0.000038 -0.000055
# 4  9.748167e-06  0.000049  0.000316  ...  1.274760e-05  0.000073  0.000116
#
# ...

# %%
dta = dta.rename(columns={'Unnamed: 0':'Date'}) 
dta = dta.set_index("Date")

# %%
dta_m = dta*10000

# %%
for col in dta_m:
    for j in range(len(dta_m[col])):
        dta_m[col][j] = dta_m[col][j] - min(dta_m[col]) + 1

# %%
dta_m.head()
# Out:
#                topic0     topic1     topic2     topic3     topic4    topic5  \
# Date
# 2015-01-01  22.734439  17.450057  11.667426  20.713212  27.982296  4.533855
# 2015-01-02  23.078866  17.649171  12.025345  21.198541  28.303385  4.574219
# 2015-01-03  23.595904  18.165068  12.654186  21.819266  29.092251  4.689611
# 2015-01-04  22.144674  16.222722  10.964755  20.241272  26.397069  4.101331
# 2015-01-05  24.770230  19.334605  13.712696  23.442879  31.374482  5.033289
#
#               topic6    topic7     topic8     topic9   topic10    topic11  \
# Date
# 2015-01-01  3.483124  8.947175  27.316387  20.927792  5.743168   9.777631
# 2015-01-02  3.550177  9.323679  27.830682  21.174129  5.775215   9.944287
# 2015-01-03  3.678045  9.764224  28.730953  22.014037  5.777831  10.462030
# 2015-01-04  3.507235  9.086797  26.365150  20.495683  5.724271   9.602341
# 2015-01-05  3.651582  9.869590  31.116277  22.880485  5.905307  10.711320
#
# ...

# %%
# 차분
for col in dta_m:
    dta_m[col] = (np.log(dta_m[col])).diff() * 100

# %%
dta_m.head()
# Out:
#                topic0     topic1     topic2     topic3     topic4     topic5  \
# Date
# 2015-01-01        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-01-02   1.503638   1.134587   3.021563   2.316059   1.140936   0.886333
# 2015-01-03   2.215581   2.881158   5.097156   2.886099   2.749045   2.491387
# 2015-01-04  -6.347612 -11.308754 -14.330205  -7.506967  -9.721886 -13.403813
# 2015-01-05  11.204554  17.548364  22.363606  14.684311  17.274190  20.476195
#
#               topic6    topic7     topic8     topic9   topic10    topic11  \
# Date
# 2015-01-01       NaN       NaN        NaN        NaN       NaN        NaN
# 2015-01-02  1.906781  4.121939   1.865229   1.170208  0.556454   1.690100
# 2015-01-03  3.538393  4.616779   3.183596   3.890018  0.045280   5.075425
# 2015-01-04 -4.755335 -7.190257  -8.593196  -7.146600 -0.931319  -8.574559
# 2015-01-05  4.033248  8.263584  16.568798  11.007009  3.113628  10.929428
#
# ...

# %%
dta_m.loc[:, 'topic0'].plot(subplots=True,  figsize=(15, 6));

# %%
# 표준화
for col in dta_m:
    dta_m[col] = (dta_m[col] - dta_m[col].mean()) / dta_m[col].std()

# %%
dta_m
# Out:
#               topic0    topic1    topic2    topic3    topic4    topic5  \
# Date
# 2015-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-01-02  0.058235  0.049630  0.100839  0.072677  0.041107  0.062103
# 2015-01-03  0.079648  0.106263  0.163097  0.087820  0.082361  0.153076
# 2015-01-04 -0.177895 -0.353845 -0.419632 -0.188270 -0.237566 -0.747848
# 2015-01-05  0.349996  0.581846  0.681010  0.401237  0.454987  1.172436
# ...              ...       ...       ...       ...       ...       ...
# 2016-12-19 -1.967663 -1.435019 -0.748853 -1.875930 -1.913066 -0.621795
# 2016-12-20  2.038561  2.422524  1.729112  2.541724  2.772036  1.358252
# 2016-12-21 -1.612271 -1.954752 -1.866149 -2.396696 -1.972467 -1.117834
# 2016-12-22 -0.387251 -0.412781 -0.224025 -0.111574 -0.764056 -0.204819
# 2016-12-23  0.013013 -0.003626  0.010207  0.011151  0.011838  0.011866
#
#               topic6    topic7    topic8    topic9   topic10   topic11  \
# Date
# ...

# %%
dta_m.describe()
# Out:
#              topic0        topic1        topic2        topic3        topic4  \
# count  7.220000e+02  7.220000e+02  7.220000e+02  7.220000e+02  7.220000e+02
# mean  -1.476197e-17 -4.920656e-18 -6.150820e-19 -1.107148e-17  4.305574e-18
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -9.271929e+00 -9.565652e+00 -6.859548e+00 -8.391144e+00 -8.867289e+00
# 25%   -1.551237e-01 -1.936176e-01 -2.355296e-01 -2.367448e-01 -2.144120e-01
# 50%    1.168518e-02  7.896315e-03  3.247295e-03  5.540560e-03  9.365895e-03
# 75%    1.720968e-01  2.132687e-01  2.430619e-01  2.460860e-01  2.231788e-01
# max    9.170766e+00  6.912832e+00  5.735189e+00  7.964723e+00  7.622652e+00
#
#            topic5        topic6      topic7        topic8        topic9  \
# count  722.000000  7.220000e+02  722.000000  7.220000e+02  7.220000e+02
# mean     0.000000  2.460328e-18    0.000000 -7.380984e-18 -2.460328e-18
# ...
